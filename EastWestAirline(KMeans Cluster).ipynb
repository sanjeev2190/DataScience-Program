# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns

# %%
X=np.random.uniform(0,1,1000)
Y=np.random.uniform(0,1,1000)
X
# Out:
# array([1.19470696e-01, 2.43103545e-01, 8.23930356e-01, 5.65248058e-01,
#        9.72347736e-01, 3.76408582e-01, 8.32448063e-01, 6.44050681e-01,
#        3.66775987e-01, 1.63977649e-01, 8.43988897e-01, 6.68461017e-01,
#        6.31979195e-01, 9.54661944e-01, 7.35938662e-01, 4.89940049e-01,
#        5.53063304e-01, 3.26940664e-01, 4.45021411e-01, 7.55001337e-01,
#        9.09612564e-01, 5.32679547e-01, 4.90604823e-01, 4.11516479e-01,
#        3.96911718e-01, 2.90305929e-02, 2.99133996e-01, 7.90808277e-01,
#        5.50730123e-01, 9.56601973e-01, 7.48714834e-01, 5.83631655e-01,
#        6.61275631e-01, 5.89472681e-01, 4.39555480e-01, 8.95073963e-02,
#        6.86016079e-01, 7.91739377e-01, 9.06863777e-04, 9.25310770e-01,
#        9.86104055e-01, 6.66275721e-01, 9.91074158e-01, 5.48357168e-01,
#        5.44292617e-01, 9.10808212e-01, 2.24913782e-01, 8.53014395e-01,
#        4.76278621e-02, 6.86096991e-01, 2.49518056e-01, 7.22305999e-01,
# ...

# %%
Y
# Out:
# array([4.04524968e-01, 1.93450369e-01, 8.20411211e-01, 3.55652144e-02,
#        8.14425925e-01, 7.91817199e-01, 4.24756365e-01, 2.58039305e-01,
#        6.61408347e-01, 4.44515321e-01, 5.76296880e-01, 5.63612738e-01,
#        5.11905344e-01, 1.64574133e-01, 3.81762040e-02, 9.78403058e-01,
#        4.45766134e-01, 1.87294806e-01, 8.86298157e-01, 4.45286771e-01,
#        6.36441723e-01, 7.60329230e-02, 5.16916107e-01, 8.68015868e-01,
#        3.50411980e-01, 6.01272104e-02, 4.37675644e-01, 4.82104367e-01,
#        2.55316702e-01, 7.10836852e-01, 3.73482248e-01, 9.93351800e-01,
#        1.46814109e-01, 9.66740005e-01, 4.51963442e-03, 8.78540171e-01,
#        8.63773060e-01, 9.52133312e-01, 1.03034723e-01, 9.22108222e-01,
#        1.93447669e-01, 5.63630727e-01, 5.25892194e-01, 5.37174180e-03,
#        7.87958066e-01, 3.53560613e-01, 2.12778185e-01, 9.41823281e-01,
#        7.77939980e-01, 1.38054910e-01, 1.22628379e-01, 4.05633112e-02,
# ...

# %%
df_xy=pd.DataFrame(columns=["X","Y"])
df_xy
df_xy.X=X
df_xy.Y=Y
df_xy
df_xy.plot(x="X",y="Y",kind="scatter")
model1=KMeans(n_clusters=5).fit(df_xy)

# %%
df_xy.plot(x="X",y="Y",c=model1.labels_,kind="scatter",s=50,cmap=plt.cm.coolwarm_r)
# Out:
# <AxesSubplot:xlabel='X', ylabel='Y'>

# %%
airline=pd.read_excel("EastWestAirline.xlsx")
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
def norm_func(i):
    x=(i-i.min())/(i.max()-i.min())
    return(x)

# %%
df_norm=norm_func(airline.iloc[:,1:])
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
df_norm.head(10)
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
# 5  0.009631         0.0       0.00        0.0        0.0     0.000000
# 6  0.049808         0.0       0.50        0.0        0.0     0.104223
# 7  0.012233         0.0       0.00        0.0        0.0     0.019910
# 8  0.259850         0.0       0.50        0.5        0.0     0.006648
# 9  0.061507         0.0       0.50        0.0        0.0     0.107803
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0     0.011628           0.000000         0.000000           0.843742     0.0
# ...

# %%
from sklearn.cluster import KMeans
fig=plt.figure(figsize=(10,8))
WCSS=[]
for i in range(1,11):
    clf=KMeans(n_clusters=i)
    clf.fit(df_norm)
    WCSS.append(clf.inertia_)
plt.plot(range(1,11),WCSS)
plt.title("Elbow Method")
plt.ylabel("WCSS")
plt.xlabel("Number of cluster")
plt.show()

# %%
 clf=KMeans(n_clusters=5)
 y_KMeans=clf.fit_predict(df_norm)

# %%
y_KMeans
clf.labels_
# Out:
# array([4, 4, 4, ..., 3, 1, 1])

# %%
y_KMeans
# Out:
# array([4, 4, 4, ..., 3, 1, 1])

# %%
clf.cluster_centers_
# Out:
# array([[ 6.93891884e-02,  6.59020789e-03,  6.46035599e-01,
#          8.09061489e-04,  5.66343042e-03,  1.19022293e-01,
#          2.00383834e-01,  7.27197078e-03,  1.18458814e-02,
#          5.32620376e-01, -4.99600361e-16],
#        [ 1.94103660e-02,  8.43565288e-03,  1.76669894e-02,
#          8.22846079e-03,  1.69409487e-03,  1.23106384e-02,
#          7.18386276e-02,  6.90024091e-03,  1.13792033e-02,
#          2.40189960e-01,  3.99680289e-15],
#        [ 4.89953609e-02,  2.60542873e-02,  3.90044577e-02,
#          1.63447251e-02,  2.22882615e-03,  3.35642727e-02,
#          1.21825219e-01,  3.34267751e-02,  5.94073285e-02,
#          5.22892182e-01,  1.00000000e+00],
#        [ 6.35352962e-02,  1.77912301e-02,  7.28960396e-01,
#          6.18811881e-04,  6.49752475e-03,  1.72970238e-01,
#          2.34903868e-01,  2.31602349e-02,  4.04212591e-02,
#          5.86139300e-01,  1.00000000e+00],
#        [ 2.92977490e-02,  8.07381776e-03,  3.05651672e-02,
# ...

# %%
clf.inertia_
# Out:
# 348.94342839013166

# %%
md=pd.Series(y_KMeans)
airline['clust']=md
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.iloc[:,1:13].groupby(airline.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0      118297.325243   73.467638   3.584142   1.001618   1.022654
# 1       33097.301357   94.131783   1.070736   1.016473   1.006783
# 2       83529.153046  290.453195   1.156018   1.032689   1.008915
# 3      108317.387376  198.336634   3.915842   1.001238   1.025990
# 4       49921.633641   89.903226   1.122120   1.019585   1.001152
#
#         Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clust
# 0      31384.393204    17.233010         224.100324         0.627832
# 1       3244.520349     6.173450         212.850775         0.603682
# 2       8850.395245    10.476969        1030.112927         3.148588
# 3      45609.657178    20.201733         713.728960         2.142327
# 4       3467.074885     6.913594         243.834101         0.728111
#
#        Days_since_enroll  Award?  clust
# clust
# 0            4419.553398     0.0    0.0
# 1            1992.402132     0.0    1.0
# ...

# %%
plt.style.use(['classic']) 
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
data=airline[(airline.clust==0)]
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 6        7    84914           0          3          1          1        27482
# 30      31   177926           0          3          1          1        20797
# 32      33   276571           0          4          1          1        42044
# 44      45   121260           0          3          1          1        18493
# 56      57    75971           0          4          1          1        34339
# ...    ...      ...         ...        ...        ...        ...          ...
# 3966  3989    91605           0          4          1          1        37840
# 3974  3997    58387           0          3          1          1        14581
# 3980  4003    28867           0          3          1          1        19169
# 3985  4008    59017           0          4          1          1        34746
# 3991  4014    39142           0          3          1          1        14981
#
# ...

# %%
airline.plot(x ="Balance",y ="cc1_miles",c=clf.labels_,kind="scatter",s=50 ,cmap=plt.cm.coolwarm) 
plt.title('Clusters using KMeans')
# Out:
# Text(0.5, 1.0, 'Clusters using KMeans')

# %%
WCSS
# Out:
# [1830.7932128584112,
#  823.6756984125205,
#  625.1684881570719,
#  436.70885761932607,
#  348.94342839013166,
#  315.3494120774195,
#  287.7280746213443,
#  263.2132188914899,
#  243.92443618938395,
#  231.74520680435526]
