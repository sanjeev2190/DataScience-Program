# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import AgglomerativeClustering

# %%
airline=pd.read_excel("EastWestAirline.xlsx")
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
def_norm = norm_func(airline.iloc[:,1:])
def_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
trans=MinMaxScaler()
data=pd.DataFrame(trans.fit_transform(airline.iloc[:,1:]))
data
# Out:
#             0    1     2    3    4         5         6         7         8   \
# 0     0.016508  0.0  0.00  0.0  0.0  0.000660  0.011628  0.000000  0.000000
# 1     0.011288  0.0  0.00  0.0  0.0  0.000815  0.023256  0.000000  0.000000
# 2     0.024257  0.0  0.00  0.0  0.0  0.015636  0.046512  0.000000  0.000000
# 3     0.008667  0.0  0.00  0.0  0.0  0.001896  0.011628  0.000000  0.000000
# 4     0.057338  0.0  0.75  0.0  0.0  0.164211  0.302326  0.067398  0.075472
# ...        ...  ...   ...  ...  ...       ...       ...       ...       ...
# 3994  0.010837  0.0  0.00  0.0  0.0  0.032330  0.046512  0.006490  0.018868
# 3995  0.037766  0.0  0.00  0.0  0.0  0.003720  0.058140  0.000000  0.000000
# 3996  0.043169  0.0  0.50  0.0  0.0  0.096505  0.093023  0.000000  0.000000
# 3997  0.032202  0.0  0.00  0.0  0.0  0.001896  0.011628  0.016225  0.018868
# 3998  0.001769  0.0  0.00  0.0  0.0  0.000000  0.000000  0.000000  0.000000
#
#             9    10
# 0     0.843742  0.0
# ...

# %%
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
z=linkage(def_norm,method="ward",metric="euclidean")
plt.figure(figsize=(20,15))
plt.title("Hirearchy Cluster Of DendoGram")
plt.xlabel("Index")
plt.ylabel("Distance")
sch.dendrogram(z)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import warnings
warnings.filterwarnings("ignore")

h_complite=AgglomerativeClustering(n_clusters=4,linkage="ward",affinity="euclidean").fit(def_norm)
cluster_label=pd.Series(h_complite.labels_)
cluster_label
airline['clust']=cluster_label
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.iloc[:,1:].groupby(airline.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0       37876.890058   52.797076   1.000000   1.019883   1.000585
# 1       79848.233615  285.097252   1.699789   1.024313   1.000000
# 2      106221.111386  161.262376   3.198020   1.001238   1.025990
# 3      127475.028037  160.801869   4.362617   1.000000   1.050467
#
#         Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clust
# 0       2558.508187     5.730994         239.314035         0.697076
# 1      12079.774841    12.133192         781.939746         2.369979
# 2      26458.257426    16.363861         198.733911         0.558168
# 3      58656.919626    22.235514         991.110280         3.005607
#
#        Days_since_enroll  Award?  clust
# clust
# 0            3562.376608     0.0    0.0
# 1            4372.173362     1.0    1.0
# 2            4367.250000     0.0    2.0
# 3            5072.226168     1.0    3.0

# %%
data=airline[(airline.clust==0)]
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3990  4013    11310           0          1          1          1         5021
# 3992  4015    11181           0          1          1          1          929
# 3993  4016     3974           0          1          1          1          365
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data=airline[(airline.Balance==28143)]
data
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
#
#    clust
# 0      0

# %%
data=airline[(airline.clust==1)]
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 7        8    20856           0          1          1          1         5250
# 8        9   443003           0          3          2          1         1753
# 9       10   104860           0          3          1          1        28426
# 17      18    13958           0          1          1          1         4291
# 18      19    91473           0          3          1          1        27408
# ...    ...      ...         ...        ...        ...        ...          ...
# 3987  4010    11933           0          1          1          1          249
# 3989  4012     2622           0          1          1          1         1625
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
airline_subset=pd.DataFrame(scaler.fit_transform(airline.iloc[:,1:12]))
airline_subset
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786 -1.104065
# 1    -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088 -0.999926
# 2    -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253 -0.791649
# 3    -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 4     0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121  1.499394
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960 -0.791649
# 3995 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367 -0.687511
# 3996 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804 -0.375096
# 3997 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286 -1.104065
# 3998 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992 -1.208203
#
#             7         8         9         10
# ...

# %%
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
z=linkage(airline_subset,method="ward",metric="euclidean")
plt.figure(figsize=(20,15))
plt.title("Hierarchey cluster of dendogram ")
plt.xlabel("index")
plt.ylabel("Distance")
sch.dendrogram(z)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import warnings
warnings.filterwarnings("ignore")

h_complite=AgglomerativeClustering(n_clusters=4,linkage="ward",affinity="euclidean").fit(airline_subset)
cluster_label=pd.Series(h_complite.labels_)
cluster_label
airline['clust']=cluster_label
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline.iloc[:,1:].groupby(airline.clust).mean()
# Out:
#              Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clust
# 0      116314.450725  363.839130   3.498551   1.000000   1.035507
# 1       46329.336877    9.028618   1.244072   1.000000   1.000000
# 2      134880.892308  393.323077   2.430769   1.000000   1.000000
# 3       68876.581395   23.255814   1.139535   2.348837   1.000000
#
#         Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clust
# 0      37150.356522    18.066667         377.000000         1.150000
# 1       4868.112428     6.907604         214.812756         0.673753
# 2      36582.169231    29.338462        5915.523077        16.638462
# 3      14689.837209    17.534884         582.627907         2.209302
#
#        Days_since_enroll    Award?  clust
# clust
# 0            4696.888406  0.663043    0.0
# 1            3769.337694  0.184383    1.0
# 2            4599.607692  0.753846    2.0
# 3            3968.930233  0.395349    3.0

# %%
data=airline[(airline.clust==0)]
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4        5    97752           0          4          1          1        43300
# 6        7    84914           0          3          1          1        27482
# 9       10   104860           0          3          1          1        28426
# 11      12    96522           0          5          1          1        61105
# 15      16    28495           0          4          1          1        49442
# ...    ...      ...         ...        ...        ...        ...          ...
# 3979  4002    57793           0          3          1          1        20959
# 3980  4003    28867           0          3          1          1        19169
# 3985  4008    59017           0          4          1          1        34746
# 3991  4014    39142           0          3          1          1        14981
# 3996  4019    73597           0          3          1          1        25447
#
# ...

# %%
data=airline[(airline.clust==1)]
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3993  4016     3974           0          1          1          1          365
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
data=airline[(airline.Balance==28143)]
data
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
#
#    clust
# 0      1

# %%
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
z=linkage(airline_subset,method="ward",metric="euclidean")
plt.figure(figsize=(20,15))
plt.title("Hierarchey cluster of dendogram ")
plt.xlabel("index")
plt.ylabel("Distance")
sch.dendrogram(z)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering
import warnings
warnings.filterwarnings("ignore")

h_complite=AgglomerativeClustering(n_clusters=4,linkage="ward",affinity="euclidean").fit(airline_subset)
cluster_label=pd.Series(h_complite.labels_)
cluster_label
airline['clust']=cluster_label
airline
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...
